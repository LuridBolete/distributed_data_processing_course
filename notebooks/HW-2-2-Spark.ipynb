# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/conda/lib/python3.10/site-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /opt/conda/lib/python3.10/site-packages (from pyspark) (0.10.9.7)

# %%
import pyspark

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %%
spark  = (SparkSession.builder
                      .appName('Dubovik_Spark')
                      .enableHiveSupport()
                      .config("spark.executor.instances", "2")
                      .config("spark.executor.cores","1")
                      .config("spark.executor.memory", "4G")
                      .config("spark.default.parallelism","2")
                      .getOrCreate())

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10c51614c5dc:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dubovik_Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
ratings_txt = spark.read.text("/kaggle/input/movielens/ratings.csv")

# %%
ratings_txt.take(5)
# Out:
# [Row(value='userId,movieId,rating,timestamp'),
#  Row(value='1,31,2.5,1260759144'),
#  Row(value='1,1029,3.0,1260759179'),
#  Row(value='1,1061,3.0,1260759182'),
#  Row(value='1,1129,2.0,1260759185')]

# %% [markdown]
# ## Блок 1

# %% [markdown]
# ### Количество строчек в датасете movielens/ratings.csv

# %%
ratings_csv = spark.read.option("header", True).csv("/kaggle/input/movielens/ratings.csv")

# %%
ratings_csv.show()
# Out:
# +------+-------+------+----------+
# |userId|movieId|rating| timestamp|
# +------+-------+------+----------+
# |     1|     31|   2.5|1260759144|
# |     1|   1029|   3.0|1260759179|
# |     1|   1061|   3.0|1260759182|
# |     1|   1129|   2.0|1260759185|
# |     1|   1172|   4.0|1260759205|
# |     1|   1263|   2.0|1260759151|
# |     1|   1287|   2.0|1260759187|
# |     1|   1293|   2.0|1260759148|
# |     1|   1339|   3.5|1260759125|
# |     1|   1343|   2.0|1260759131|
# |     1|   1371|   2.5|1260759135|
# |     1|   1405|   1.0|1260759203|
# |     1|   1953|   4.0|1260759191|
# |     1|   2105|   4.0|1260759139|
# |     1|   2150|   3.0|1260759194|
# |     1|   2193|   2.0|1260759198|
# |     1|   2294|   2.0|1260759108|
# |     1|   2455|   2.5|1260759113|
# |     1|   2968|   1.0|1260759200|
# |     1|   3671|   3.0|1260759117|
# +------+-------+------+----------+
# only showing top 20 rows

# %%
ratings_csv.count()
# Out:
# 100004

# %% [markdown]
# ### Количество строчек в датасете movielens/tags.csv

# %%
tags_csv = spark.read.option("header", True).csv("/kaggle/input/movielens/tags.csv")

# %%
tags_csv.show()
# Out:
# +------+-------+--------------------+----------+
# |userId|movieId|                 tag| timestamp|
# +------+-------+--------------------+----------+
# |    15|    339|sandra 'boring' b...|1138537770|
# |    15|   1955|             dentist|1193435061|
# |    15|   7478|            Cambodia|1170560997|
# |    15|  32892|             Russian|1170626366|
# |    15|  34162|         forgettable|1141391765|
# |    15|  35957|               short|1141391873|
# |    15|  37729|          dull story|1141391806|
# |    15|  45950|          powerpoint|1169616291|
# |    15| 100365|            activist|1425876220|
# |    15| 100365|         documentary|1425876220|
# |    15| 100365|              uganda|1425876220|
# |    23|    150|          Ron Howard|1148672905|
# |    68|   2174|               music|1249808064|
# |    68|   2174|               weird|1249808102|
# |    68|   8623|        Steve Martin|1249808497|
# |    73| 107999|              action|1430799184|
# |    73| 107999|               anime|1430799184|
# |    73| 107999|             kung fu|1430799184|
# |    73| 111624|               drama|1431584497|
# |    73| 111624|               indie|1431584497|
# +------+-------+--------------------+----------+
# only showing top 20 rows

# %%
tags_csv.count()
# Out:
# 1296

# %% [markdown]
# ## Блок 2

# %%
ratings_csv.createOrReplaceTempView("ratings_csv")
tags_csv.createOrReplaceTempView("tags_csv")

# %% [markdown]
# ### Количество уникальных фильмов и юзеров в таблице “ratings”

# %%
ratings_csv.printSchema()
# Out:
# root
#  |-- userId: string (nullable = true)
#  |-- movieId: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
query = ''' SELECT 
                COUNT(DISTINCT userId) AS Number_of_unique_users,
                COUNT(DISTINCT movieId) AS Number_of_unique_movies
            FROM ratings_csv
        '''

# %%
unique_elems = spark.sql(query)

# %%
unique_elems.show()
# Out:
# +----------------------+-----------------------+
# |Number_of_unique_users|Number_of_unique_movies|
# +----------------------+-----------------------+
# |                   671|                   9066|
# +----------------------+-----------------------+

# %% [markdown]
# ### Количество оценок >= 4.0

# %%
query = ''' SELECT COUNT(userId) AS Score_greater_than_4
            FROM ratings_csv
            WHERE rating >= 4
        '''

# %%
score_greater_than_4 = spark.sql(query)

# %%
score_greater_than_4.show()
# Out:
# +--------------------+
# |Score_greater_than_4|
# +--------------------+
# |               51568|
# +--------------------+

# %% [markdown]
# ### Топ 100 фильмов с самым высоким рейтингом

# %%
query = ''' SELECT 
                movieId,
                AVG(rating) AS Average_rating,
                COUNT(userId) AS Number_of_assessments
            FROM ratings_csv
            GROUP BY movieId
            ORDER BY 
                Average_rating DESC,
                Number_of_assessments DESC
        '''

# %%
top_movies = spark.sql(query)

# %%
top_movies.show(100)
# Out:
# +-------+--------------+---------------------+
# |movieId|Average_rating|Number_of_assessments|
# +-------+--------------+---------------------+
# |   3038|           5.0|                    4|
# |    309|           5.0|                    3|
# |   3112|           5.0|                    3|
# |  32525|           5.0|                    2|
# |   7087|           5.0|                    2|
# |  74727|           5.0|                    2|
# |  99764|           5.0|                    2|
# |   9010|           5.0|                    2|
# |    759|           5.0|                    2|
# |   6598|           5.0|                    2|
# |   1859|           5.0|                    2|
# |   6918|           5.0|                    2|
# |   4466|           5.0|                    1|
# |  26843|           5.0|                    1|
# |  77291|           5.0|                    1|
# |   7208|           5.0|                    1|
# |  26094|           5.0|                    1|
# |   5960|           5.0|                    1|
# | 112577|           5.0|                    1|
# | 140761|           5.0|                    1|
# |   5071|           5.0|                    1|
# |  79469|           5.0|                    1|
# |   8699|           5.0|                    1|
# | 118890|           5.0|                    1|
# |   4789|           5.0|                    1|
# | 142240|           5.0|                    1|
# |  86487|           5.0|                    1|
# |   3909|           5.0|                    1|
# |   5101|           5.0|                    1|
# |   2573|           5.0|                    1|
# | 102217|           5.0|                    1|
# |  26422|           5.0|                    1|
# |   8261|           5.0|                    1|
# |  26150|           5.0|                    1|
# |   4731|           5.0|                    1|
# | 141124|           5.0|                    1|
# |   5866|           5.0|                    1|
# |   5473|           5.0|                    1|
# |   1543|           5.0|                    1|
# |   1428|           5.0|                    1|
# |   3837|           5.0|                    1|
# |   4584|           5.0|                    1|
# |  91673|           5.0|                    1|
# | 161944|           5.0|                    1|
# |  99030|           5.0|                    1|
# | 153584|           5.0|                    1|
# |  27792|           5.0|                    1|
# |   2562|           5.0|                    1|
# |   4617|           5.0|                    1|
# |   4717|           5.0|                    1|
# |  80839|           5.0|                    1|
# |  98963|           5.0|                    1|
# |  69761|           5.0|                    1|
# |  59549|           5.0|                    1|
# |  25852|           5.0|                    1|
# | 107649|           5.0|                    1|
# |   4796|           5.0|                    1|
# |  59273|           5.0|                    1|
# |  26791|           5.0|                    1|
# | 148372|           5.0|                    1|
# |   4140|           5.0|                    1|
# |  58649|           5.0|                    1|
# |  80717|           5.0|                    1|
# | 129313|           5.0|                    1|
# | 150856|           5.0|                    1|
# | 107555|           5.0|                    1|
# |   6769|           5.0|                    1|
# |  32460|           5.0|                    1|
# | 139116|           5.0|                    1|
# |   4930|           5.0|                    1|
# |   4201|           5.0|                    1|
# |  27592|           5.0|                    1|
# |  31903|           5.0|                    1|
# |  26578|           5.0|                    1|
# |   2649|           5.0|                    1|
# | 100553|           5.0|                    1|
# | 107978|           5.0|                    1|
# |   3757|           5.0|                    1|
# |   3737|           5.0|                    1|
# |   3656|           5.0|                    1|
# |   3281|           5.0|                    1|
# |   4626|           5.0|                    1|
# |  59684|           5.0|                    1|
# |  65037|           5.0|                    1|
# | 136449|           5.0|                    1|
# | 136447|           5.0|                    1|
# |  67504|           5.0|                    1|
# | 140755|           5.0|                    1|
# |  48791|           5.0|                    1|
# |   1692|           5.0|                    1|
# |   3437|           5.0|                    1|
# |   5062|           5.0|                    1|
# |   2981|           5.0|                    1|
# |  42900|           5.0|                    1|
# |    876|           5.0|                    1|
# |   3447|           5.0|                    1|
# |   3021|           5.0|                    1|
# |   1563|           5.0|                    1|
# |  62115|           5.0|                    1|
# |   4088|           5.0|                    1|
# +-------+--------------+---------------------+
# only showing top 100 rows

# %% [markdown]
# ### Средняя разница между timestamp'ами проставления тегов и рейтинга

# %%
query = ''' SELECT 
                t.*,
                ratings_csv.timestamp AS timestamp_rate,
                timestamp_tag-timestamp_rate AS timedelta_between_tag_and_rate
            FROM 
                (SELECT 
                    MAX(tags_csv.movieId) AS movieId,
                    MAX(tags_csv.userId) AS userId,
                    AVG(tags_csv.timestamp) AS timestamp_tag
                FROM tags_csv
                GROUP BY
                    tags_csv.movieId,
                    tags_csv.userId) AS t
            LEFT JOIN ratings_csv
            WHERE 
                t.movieId = ratings_csv.movieId
                AND t.userId = ratings_csv.userId
        '''

# %%
timedelta_between_tag_and_rate = spark.sql(query)

# %%
timedelta_between_tag_and_rate.show()
# Out:
# +-------+------+--------------+--------------+------------------------------+
# |movieId|userId| timestamp_tag|timestamp_rate|timedelta_between_tag_and_rate|
# +-------+------+--------------+--------------+------------------------------+
# |    339|    15|  1.13853777E9|    1122576622|                   1.5961148E7|
# |   1955|    15| 1.193435061E9|    1338698424|                 -1.45263363E8|
# |  34162|    15| 1.141391765E9|    1141391741|                          24.0|
# |  35957|    15| 1.141391873E9|    1141391844|                          29.0|
# |  37729|    15| 1.141391806E9|    1141391812|                          -6.0|
# |  45950|    15| 1.169616291E9|    1169616283|                           8.0|
# | 100365|    15|  1.42587622E9|    1361831156|                   6.4045064E7|
# |    150|    23| 1.148672905E9|    1148672933|                         -28.0|
# |   2174|    68| 1.249808083E9|    1249808034|                          49.0|
# |   8623|    68| 1.249808497E9|    1249808534|                         -37.0|
# | 107999|    73| 1.430799184E9|    1398570071|                   3.2229113E7|
# | 111624|    73| 1.431584497E9|    1423801674|                     7782823.0|
# | 130682|    73| 1.432523704E9|    1432523179|                         525.0|
# |   1199|    77| 1.163220043E9|    1163219937|                         106.0|
# |   2968|    77|1.1632200885E9|    1163004536|                      215552.5|
# |   4467|    77| 1.163220065E9|    1163219953|                         112.0|
# |    296|    84| 1.429911417E9|    1429910837|                         580.0|
# |   1131|    94|  1.29178154E9|    1291781501|                          39.0|
# |  64957|    94| 1.291781246E9|    1291781225|                          21.0|
# |  74458|    94|  1.29178092E9|    1291780910|                          10.0|
# +-------+------+--------------+--------------+------------------------------+
# only showing top 20 rows

# %%
timedelta_between_tag_and_rate.agg({'timedelta_between_tag_and_rate': 'avg'}).show()
# Out:
# +-----------------------------------+
# |avg(timedelta_between_tag_and_rate)|
# +-----------------------------------+
# |                  415369.8411245346|
# +-----------------------------------+

# %% [markdown]
# ### Средняя оценка по пользователям

# %%
query = ''' SELECT 
                AVG(userId) AS userId,
                AVG(rating) AS average_rating
            FROM 
                ratings_csv
            GROUP BY userId
        '''

# %%
average_rating = spark.sql(query)

# %%
average_rating.show()
# Out:
# +------+------------------+
# |userId|    average_rating|
# +------+------------------+
# | 296.0|             3.975|
# | 467.0|             3.875|
# | 125.0| 4.023809523809524|
# | 451.0|3.6538461538461537|
# | 666.0|              2.95|
# |   7.0| 3.465909090909091|
# |  51.0| 3.967741935483871|
# | 124.0|3.7588235294117647|
# | 447.0|3.0229885057471266|
# | 591.0|3.2333333333333334|
# | 307.0| 4.263888888888889|
# | 475.0| 2.761832061068702|
# | 574.0|3.5116959064327484|
# | 613.0| 3.792452830188679|
# | 169.0| 4.110619469026549|
# | 205.0|3.4101941747572817|
# | 334.0| 3.985294117647059|
# | 544.0| 4.472014925373134|
# | 577.0| 4.345878136200717|
# | 581.0|1.4591836734693877|
# +------+------------------+
# only showing top 20 rows

# %%
average_rating.agg({'average_rating': 'avg'}).show()
# Out:
# +-------------------+
# |avg(average_rating)|
# +-------------------+
# | 3.6575868932068687|
# +-------------------+

# %% [markdown]
# ## Блок 3

# %%
from pyspark.sql import functions as f
from pyspark.sql.types import *

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDRegressor

# %%
df_tags = tags_csv.toPandas()
df_ratings = ratings_csv.toPandas()

# %%
df_tags = df_tags.groupby(['movieId'])['tag'].apply(lambda x: ' '.join(x)).reset_index()
df_ratings[['rating']] = df_ratings[['rating']].astype(float)
df_ratings = df_ratings.groupby(['movieId'])['rating'].mean().reset_index()

df = df_tags.merge(df_ratings, on='movieId')
df
# Out:
#     movieId                                               tag    rating
# 0         1                                             Pixar  3.872470
# 1    100365                       activist documentary uganda  2.500000
# 2    101285                                            getdvd  3.166667
# 3    101525                                         toplist12  3.900000
# 4    101895                                         toplist13  3.166667
# ..      ...                                               ...       ...
# 625   97938  Ang Lee India ocean visually appealing toplist12  3.772727
# 626   98154                                         toplist12  3.428571
# 627   98961                                         toplist12  3.590909
# 628   99114                                         toplist12  3.977273
# 629   99149                                         toplist12  3.333333
#
# [630 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['tag'], 
                                                    df['rating'], 
                                                    train_size=0.8, 
                                                    random_state=42)

# %%
vect_word = TfidfVectorizer(
    max_features=1000,
    lowercase=True,
    analyzer="word",
    ngram_range=(1, 6),
    dtype=np.float32
)

# %%
# Train tf-idf
X_train_tfidf = vect_word.fit_transform(X_train)

# %%
# Init SGDRegressor
sgd_reg = SGDRegressor(random_state=42)

# %%
sgd_reg.fit(X_train_tfidf, y_train)
# Out:
# SGDRegressor(random_state=42)

# %%
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_test
# Out:
#                                 tag    rating
# 497                    martial arts  3.863636
# 244                     forgettable  3.547619
# 552                       toplist10  3.925000
# 213                   controversial  3.322785
# 549                       toplist10  3.630435
# ..                              ...       ...
# 388                       toplist07  4.222222
# 322                           jesus  4.750000
# 218                          stupid  2.026316
# 462  kung fu martial arts well done  3.958333
# 511                       toplist09  3.500000
#
# [126 rows x 2 columns]

# %%
spark_df_test = spark.createDataFrame(df_test)

# %%
spark_df_test.show()
# Out:
# +--------------------+------------------+
# |                 tag|            rating|
# +--------------------+------------------+
# |        martial arts|3.8636363636363638|
# |         forgettable|3.5476190476190474|
# |           toplist10|             3.925|
# |       controversial|3.3227848101265822|
# |           toplist10| 3.630434782608696|
# |           toplist09| 3.480769230769231|
# |aliens franchise ...|3.1923076923076925|
# |          space star|3.5172413793103448|
# |            holes70s|3.3333333333333335|
# |demons horror pos...|         3.7265625|
# |          dull story| 3.738095238095238|
# |action anime kung fu|               3.5|
# |           toplist14|2.7777777777777777|
# |              getdvd|               2.0|
# |           toplist08|3.9473684210526314|
# |    getdvd toplist15|3.7903225806451615|
# |              getdvd|3.1666666666666665|
# |sci fi spock Star...|3.8333333333333335|
# |cool and great mu...|               4.2|
# |                 dvd|               4.0|
# +--------------------+------------------+
# only showing top 20 rows

# %%
@f.pandas_udf(DoubleType())
def pred_rate(tags):
    # Map tf-idf on test
    X_test_tfidf = vect_word.transform(tags).toarray()
    output = tags.apply(lambda x: sgd_reg.predict(X_test_tfidf))
    return pd.Series(output[0])

# %%
# %%time
spark_df_test\
    .withColumn("pred", pred_rate(f.col("tag")))\
    .collect()
# Out:
# [Stage 290:>                                                        (0 + 2) / 2]
# CPU times: user 18.1 ms, sys: 3.17 ms, total: 21.3 ms
# Wall time: 1.46 s
# [Row(tag='martial arts', rating=3.8636363636363638, pred=3.0397504225961516),
#  Row(tag='forgettable', rating=3.5476190476190474, pred=1.5856514730325881),
#  Row(tag='toplist10', rating=3.925, pred=3.8464636328436774),
#  Row(tag='controversial', rating=3.3227848101265822, pred=1.5856514730325881),
#  Row(tag='toplist10', rating=3.630434782608696, pred=3.8464636328436774),
#  Row(tag='toplist09', rating=3.480769230769231, pred=3.827122694061394),
#  Row(tag='aliens franchise funny time travel', rating=3.1923076923076925, pred=2.7968947307457435),
#  Row(tag='space star', rating=3.5172413793103448, pred=1.7875792021300634),
#  Row(tag='holes70s', rating=3.3333333333333335, pred=3.782419642486927),
#  Row(tag='demons horror possession scary', rating=3.7265625, pred=1.9222805863598385),
#  Row(tag='dull story', rating=3.738095238095238, pred=1.9766660389255515),
#  Row(tag='action anime kung fu', rating=3.5, pred=3.0926351029386536),
#  Row(tag='toplist14', rating=2.7777777777777777, pred=3.810116870515477),
#  Row(tag='getdvd', rating=2.0, pred=3.5416198722745573),
#  Row(tag='toplist08', rating=3.9473684210526314, pred=4.05773635177164),
#  Row(tag='getdvd toplist15', rating=3.7903225806451615, pred=4.725353674582599),
#  Row(tag='getdvd', rating=3.1666666666666665, pred=3.5416198722745573),
#  Row(tag='sci fi spock Star Trek teleportation', rating=3.8333333333333335, pred=3.1889995520240784),
#  Row(tag='cool and great music nonlinear time travel', rating=4.2, pred=2.2229193202102944),
#  Row(tag='dvd', rating=4.0, pred=2.887576730623843),
#  Row(tag='toplist16', rating=5.0, pred=1.5856514730325881),
#  Row(tag='long classic', rating=4.277777777777778, pred=2.534048199273393),
#  Row(tag='toplist14 determination devotion music', rating=3.875, pred=3.0579906822032212),
#  Row(tag='toplist12', rating=3.4285714285714284, pred=3.9132110127256836),
#  Row(tag='Brad Pitt ending gratuitous violence Quentin Tarantino satire unusual plot structure violence World War II Quentin Tarantino toplist09', rating=4.135593220338983, pred=3.312145420661371),
#  Row(tag='not too thrilled', rating=3.5, pred=1.9651165636861396),
#  Row(tag='holes40s', rating=4.363636363636363, pred=3.7139391669316812),
#  Row(tag='toplist11', rating=3.9444444444444446, pred=3.945861317127036),
#  Row(tag='Ang Lee India ocean visually appealing toplist12', rating=3.772727272727273, pred=2.8805364211995754),
#  Row(tag='psychology', rating=4.083333333333333, pred=2.7287654082674875),
#  Row(tag='holes90s', rating=4.666666666666667, pred=3.7337812426334187),
#  Row(tag='Nudity (Rear) Nudity (Topless) sexy food', rating=3.05, pred=2.6695419197787316),
#  Row(tag='holes40s', rating=4.0, pred=3.7139391669316812),
#  Row(tag='okay', rating=3.5, pred=1.5856514730325881),
#  Row(tag='genius intellectual mathematics psychology', rating=4.140127388535032, pred=2.39893025836069),
#  Row(tag='Michael Mann', rating=2.7, pred=1.5856514730325881),
#  Row(tag='sightsound', rating=3.8333333333333335, pred=3.888204112049361),
#  Row(tag='toplist12', rating=4.0, pred=3.9132110127256836),
#  Row(tag='breathtaking toplist06', rating=3.9324324324324325, pred=3.5728896435341184),
#  Row(tag='toplist06', rating=3.25, pred=3.5728896435341184),
#  Row(tag='Ei muista not by book', rating=3.8260869565217392, pred=3.218760914726448),
#  Row(tag='cult film Martin Scorsese social commentary', rating=4.22457627118644, pred=2.5197196671136552),
#  Row(tag='alternate reality Bill Murray character development comedy existentialism feel-good funny love romantic self discovery', rating=3.8393939393939394, pred=3.2930320893703784),
#  Row(tag='beer guy movie Just stupid', rating=2.6875, pred=2.3898636745524358),
#  Row(tag='tosee', rating=3.5, pred=1.5856514730325881),
#  Row(tag='interesting', rating=3.9563492063492065, pred=3.028456652251105),
#  Row(tag='vampire', rating=3.1904761904761907, pred=1.5856514730325881),
#  Row(tag='the best comic adaptation!', rating=3.625, pred=2.264212603913167),
#  Row(tag='sightsound', rating=3.85, pred=3.888204112049361),
#  Row(tag='beautifully filmed comedy feel-good imagination love notable soundtrack quirky whimsical comedy drama notable soundtrack quirky', rating=4.096, pred=3.274831487584326),
#  Row(tag='sightsound', rating=3.8333333333333335, pred=3.888204112049361),
#  Row(tag='martial arts', rating=3.8552631578947367, pred=3.0397504225961516),
#  Row(tag='toplist13', rating=3.875, pred=3.8201789658842444),
#  Row(tag='National Film Registry', rating=3.5357142857142856, pred=2.0766938800292825),
#  Row(tag='Satoshi Kon', rating=3.8333333333333335, pred=1.5856514730325881),
#  Row(tag='dark comedy Guy Ritchie organized crime', rating=4.128378378378378, pred=3.3851563627894996),
#  Row(tag='cult film dark comedy satirical great dialogue Jeff Bridges Nudity (Full Frontal) off-beat comedy quirky satirical Steve Buscemi', rating=3.995833333333333, pred=3.5718450854252057),
#  Row(tag='toplist08', rating=3.25, pred=4.05773635177164),
#  Row(tag='afi', rating=4.25, pred=3.549490249130982),
#  Row(tag='dark comedy dark humor John Cleese quirky', rating=3.9719101123595504, pred=3.5946441225824),
#  Row(tag='comedy zombies', rating=3.8714285714285714, pred=3.037807345131112),
#  Row(tag='explosions martial arts', rating=3.769230769230769, pred=3.371022618828148),
#  Row(tag='toplist06', rating=4.2023809523809526, pred=3.5728896435341184),
#  Row(tag='toplist14', rating=3.7, pred=3.810116870515477),
#  Row(tag='Beautiful Woman campy irreverent quirky Roman Polanski', rating=3.5, pred=2.2752738450728334),
#  Row(tag='sightsound', rating=3.78125, pred=3.888204112049361),
#  Row(tag='tcm', rating=3.0, pred=3.564512920391784),
#  Row(tag='toplist07', rating=3.7333333333333334, pred=4.0119417856677275),
#  Row(tag='toplist09', rating=3.5, pred=3.827122694061394),
#  Row(tag='toplist07', rating=3.7857142857142856, pred=4.0119417856677275),
#  Row(tag='music weird Micheal Keaton', rating=3.4375, pred=1.7435066078079986),
#  Row(tag='toplist13', rating=3.75, pred=3.8201789658842444),
#  Row(tag='Marx Brothers', rating=4.132352941176471, pred=1.5856514730325881),
#  Row(tag='hdtv holes00s', rating=3.6666666666666665, pred=3.3382138724113757),
#  Row(tag='Takashi Miike', rating=3.6666666666666665, pred=1.5856514730325881),
#  Row(tag='toplist11', rating=3.642857142857143, pred=3.945861317127036),
#  Row(tag='Benicio Del Toro', rating=3.316666666666667, pred=1.5856514730325881),
#  Row(tag='Katso Sanna!', rating=3.924, pred=3.5554274464248525),
#  Row(tag='toplist07', rating=3.5, pred=4.0119417856677275),
#  Row(tag='cocaine crude humor directorial debut Mark Wahlberg', rating=2.95, pred=1.9081329016392088),
#  Row(tag='holes70s', rating=5.0, pred=3.782419642486927),
#  Row(tag='toplist14', rating=2.6666666666666665, pred=3.810116870515477),
#  Row(tag='anime children fantasy atmospheric surreal', rating=4.134920634920635, pred=3.657301104693924),
#  Row(tag='toplist07', rating=3.75, pred=4.0119417856677275),
#  Row(tag='Ralph Fiennes', rating=3.75, pred=1.5856514730325881),
#  Row(tag='toplist11', rating=3.3, pred=3.945861317127036),
#  Row(tag='meg ryan', rating=3.3583333333333334, pred=1.6953483770193034),
#  Row(tag='holes70s', rating=3.923076923076923, pred=3.782419642486927),
#  Row(tag='holes80s', rating=3.9444444444444446, pred=4.083386958848142),
#  Row(tag='getdvd holes60s', rating=3.4166666666666665, pred=4.486208147954071),
#  Row(tag='creative funny Helen Hunt hilarious Mel Gibson stereotypes', rating=3.125, pred=2.7255785085283435),
#  Row(tag='toplist08', rating=3.0, pred=4.05773635177164),
#  Row(tag='Alex van Warmerdam magical realism weird', rating=5.0, pred=1.5856514730325881),
#  Row(tag='tivo', rating=3.0357142857142856, pred=3.5193626759518537),
#  Row(tag='toplist15', rating=4.0, pred=4.063298037442578),
#  Row(tag='holes80s', rating=3.704081632653061, pred=4.083386958848142),
#  Row(tag='holes90s', rating=3.973684210526316, pred=3.7337812426334187),
#  Row(tag='renee z', rating=2.8095238095238093, pred=1.5856514730325881),
#  Row(tag='Katso Sanna!', rating=3.4545454545454546, pred=3.5554274464248525),
#  Row(tag='Bill Murray quirky', rating=3.3448275862068964, pred=2.1223704254275066),
#  Row(tag='dark comedy psychology twist ending', rating=4.178217821782178, pred=4.167025949048581),
#  Row(tag='fantasy feel-good', rating=4.230769230769231, pred=2.506030960553784),
#  Row(tag='high school Kristen Stewart Robert Pattinson Teen movie Vampire Human Love romance Teen movie vampires', rating=2.5384615384615383, pred=2.5199711693772886),
#  Row(tag='toplist11', rating=3.5, pred=3.945861317127036),
#  Row(tag='toplist06', rating=3.75, pred=3.5728896435341184),
#  Row(tag='war', rating=4.138461538461539, pred=1.5856514730325881),
#  Row(tag='comedy martial arts Stephen Chow', rating=3.6578947368421053, pred=3.4978459101383614),
#  Row(tag='toplist15', rating=3.5, pred=4.063298037442578),
#  Row(tag='Ei muista', rating=3.8777777777777778, pred=3.732504068101839),
#  Row(tag='Takashi Miike', rating=2.5, pred=1.5856514730325881),
#  Row(tag='holes80s', rating=4.260869565217392, pred=4.083386958848142),
#  Row(tag='holes80s', rating=3.625, pred=4.083386958848142),
#  Row(tag='action aliens George Lucas Harrison Ford sci-fi sequel space Star Wars starship pilots war', rating=4.059907834101383, pred=2.908640873859275),
#  Row(tag='tivo', rating=3.75, pred=3.5193626759518537),
#  Row(tag='boring', rating=3.05, pred=3.23472282344183),
#  Row(tag='toplist15', rating=3.5, pred=4.063298037442578),
#  Row(tag='toplist11', rating=3.78125, pred=3.945861317127036),
#  Row(tag='ei muista', rating=3.142857142857143, pred=3.732504068101839),
#  Row(tag='toplist07', rating=3.3378378378378377, pred=4.0119417856677275),
#  Row(tag='akira kurosawa black comedy atmospheric', rating=4.166666666666667, pred=2.7205428188582417),
#  Row(tag='holes40s', rating=4.333333333333333, pred=3.7139391669316812),
#  Row(tag='toplist07', rating=4.222222222222222, pred=4.0119417856677275),
#  Row(tag='jesus', rating=4.75, pred=2.759805495486564),
#  Row(tag='stupid', rating=2.026315789473684, pred=1.5856514730325881),
#  Row(tag='kung fu martial arts well done', rating=3.9583333333333335, pred=3.0397504225961516),
#  Row(tag='toplist09', rating=3.5, pred=3.827122694061394)]

# %%
# %%time
spark_df_test = spark_df_test.withColumn("pred", pred_rate(f.col("tag")))
# Out:
# CPU times: user 2.14 ms, sys: 125 µs, total: 2.27 ms
# Wall time: 6.98 ms

# %%
spark_df_test.show()
# Out:
# +--------------------+------------------+------------------+
# |                 tag|            rating|              pred|
# +--------------------+------------------+------------------+
# |        martial arts|3.8636363636363638|3.0397504225961516|
# |         forgettable|3.5476190476190474|1.5856514730325881|
# |           toplist10|             3.925|3.8464636328436774|
# |       controversial|3.3227848101265822|1.5856514730325881|
# |           toplist10| 3.630434782608696|3.8464636328436774|
# |           toplist09| 3.480769230769231| 3.827122694061394|
# |aliens franchise ...|3.1923076923076925|2.7968947307457435|
# |          space star|3.5172413793103448|1.7875792021300634|
# |            holes70s|3.3333333333333335| 3.782419642486927|
# |demons horror pos...|         3.7265625|1.9222805863598385|
# |          dull story| 3.738095238095238|1.9766660389255515|
# |action anime kung fu|               3.5|3.0926351029386536|
# |           toplist14|2.7777777777777777| 3.810116870515477|
# |              getdvd|               2.0|3.5416198722745573|
# |           toplist08|3.9473684210526314|  4.05773635177164|
# |    getdvd toplist15|3.7903225806451615| 4.725353674582599|
# |              getdvd|3.1666666666666665|3.5416198722745573|
# |sci fi spock Star...|3.8333333333333335|3.1889995520240784|
# |cool and great mu...|               4.2|2.2229193202102944|
# |                 dvd|               4.0| 2.887576730623843|
# +--------------------+------------------+------------------+
# only showing top 20 rows

# %%
spark_df_test.createOrReplaceTempView("spark_df_test")

# %%
query = ''' SELECT SQRT(AVG(squared_error)) AS RMSE
            FROM
                (SELECT 
                    *,
                    POW (rating - pred, 2) AS squared_error
                FROM 
                    spark_df_test)
        '''

# %%
rmse = spark.sql(query)

# %%
rmse.show()
# Out:
# +------------------+
# |              RMSE|
# +------------------+
# |1.1030680377369404|
# +------------------+
